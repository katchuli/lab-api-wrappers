# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# 2. find url and store it in a variable
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
# response.content

# %% [markdown]
# ### 1. TOP 100 songs

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup.select('div.chart-content.col-xs-12.col-sm-8 > p > cite')
# Out:
# [<cite class="title">TEXAS HOLD 'EM</cite>,
#  <cite class="title">Beautiful Things</cite>,
#  <cite class="title">Lose Control</cite>,
#  <cite class="title">Run Back To You</cite>,
#  <cite class="title">Wine Into Whiskey</cite>,
#  <cite class="title">The Machine</cite>,
#  <cite class="title">TEXAS HOLD 'EM</cite>,
#  <cite class="title">Lovin On Me</cite>,
#  <cite class="title">Flowers</cite>,
#  <cite class="title">Drown</cite>,
#  <cite class="title">Don't Let the Old Man In</cite>,
#  <cite class="title">Made For Me</cite>,
#  <cite class="title">Beautiful Things (Acoustic)</cite>,
#  <cite class="title">Fast Car</cite>,
#  <cite class="title">Beautiful Things (Slowed Down)</cite>,
#  <cite class="title">Beautiful Things (Sped Up)</cite>,
#  <cite class="title">Selfish</cite>,
#  <cite class="title">Love On</cite>,
#  <cite class="title">Made In China</cite>,
#  <cite class="title">Where the Wild Things Are</cite>,
#  <cite class="title">Holy Smokes</cite>,
#  <cite class="title">FAKE LOVE</cite>,
#  <cite class="title">Houdini</cite>,
#  <cite class="title">Live Like You Were Dying</cite>,
#  <cite class="title">I Remember Everything (feat. Kacey Musgraves)</cite>,
#  <cite class="title">Friendly Fire</cite>,
#  <cite class="title">Lil Boo Thang</cite>,
#  <cite class="title">Stand United (feat. Buju Banton)</cite>,
#  <cite class="title">Cruel Summer</cite>,
#  <cite class="title">Beautiful Things (Instrumental)</cite>,
#  <cite class="title">Need a Favor</cite>,
#  <cite class="title">Where They At</cite>,
#  <cite class="title">Save Me</cite>,
#  <cite class="title">Beautiful Things (Acapella)</cite>,
#  <cite class="title">GOOD DAY</cite>,
#  <cite class="title">Turn the Lights Back On</cite>,
#  <cite class="title">dont let me go</cite>,
#  <cite class="title">Save Me (with Lainey Wilson)</cite>,
#  <cite class="title">Fast Car</cite>,
#  <cite class="title">The Sound of Silence (CYRIL Remix)</cite>,
#  <cite class="title">Thinkin’ Bout Me</cite>,
#  <cite class="title">Spin You Around (1/24)</cite>,
#  <cite class="title">Splash Brothers</cite>,
#  <cite class="title">Yeah! (feat. Lil Jon &amp; Ludacris)</cite>,
#  <cite class="title">Wildflowers and Wild Horses (Single Version)</cite>,
#  <cite class="title">Beautiful Things (Piano Instrumental)</cite>,
#  <cite class="title">Space in My Heart</cite>,
#  <cite class="title">Pretty Little Poison</cite>,
#  <cite class="title">White Horse</cite>,
#  <cite class="title">16 CARRIAGES</cite>,
#  <cite class="title">TRUCK BED</cite>,
#  <cite class="title">Murder On the Dancefloor (Radio Edit)</cite>,
#  <cite class="title">Hard to Love</cite>,
#  <cite class="title">What Was I Made For? (From The Motion Picture "Barbie")</cite>,
#  <cite class="title">Stick Season</cite>,
#  <cite class="title">Tennessee Whiskey</cite>,
#  <cite class="title">23</cite>,
#  <cite class="title">Water</cite>,
#  <cite class="title">Last Night</cite>,
#  <cite class="title">The Door</cite>,
#  <cite class="title">Dance The Night</cite>,
#  <cite class="title">Powerful Women</cite>,
#  <cite class="title">Should've Been a Cowboy</cite>,
#  <cite class="title">Praise Jah In the Moonlight</cite>,
#  <cite class="title">Saturn</cite>,
#  <cite class="title">Anti-Hero</cite>,
#  <cite class="title">A Country Boy Can Survive</cite>,
#  <cite class="title">Lover</cite>,
#  <cite class="title">Lovin On Me</cite>,
#  <cite class="title">Love Story (Taylor’s Version)</cite>,
#  <cite class="title">The Resistance</cite>,
#  <cite class="title">To Be A Man (feat. Darius Rucker)</cite>,
#  <cite class="title">Life With You</cite>,
#  <cite class="title">Bulletproof</cite>,
#  <cite class="title">Pretty Bird</cite>,
#  <cite class="title">Karma</cite>,
#  <cite class="title">Spicy Margarita</cite>,
#  <cite class="title">You Need To Calm Down</cite>,
#  <cite class="title">Calm Down</cite>,
#  <cite class="title">Devil You Know</cite>,
#  <cite class="title">Training Season</cite>,
#  <cite class="title">ONE SPARK</cite>,
#  <cite class="title">Paint The Town Red</cite>,
#  <cite class="title">Wondering Why</cite>,
#  <cite class="title">redrum</cite>,
#  <cite class="title">American Girl</cite>,
#  <cite class="title">...Ready For It?</cite>,
#  <cite class="title">You Belong With Me (Taylor’s Version)</cite>,
#  <cite class="title">Watermelon Moonshine</cite>,
#  <cite class="title">vampire</cite>,
#  <cite class="title">A Symptom Of Being Human</cite>,
#  <cite class="title">Is It Over Now? (Taylor's Version) [From The Vault]</cite>,
#  <cite class="title">Unstoppable</cite>,
#  <cite class="title">Burn It Down</cite>,
#  <cite class="title">Wild Ones (Extended Version)</cite>,
#  <cite class="title">greedy</cite>,
#  <cite class="title">Scared To Start</cite>,
#  <cite class="title">Unwritten</cite>,
#  <cite class="title">Party In the U.S.A.</cite>,
#  <cite class="title">Shivers</cite>]

# %%
len(soup.select('div.chart-content.col-xs-12.col-sm-8 > p > cite'))
# Out:
# 100

# %%
soup.select('div.chart-content.col-xs-12.col-sm-8 > p > em')
# Out:
# [<em class="artist">Beyoncé</em>,
#  <em class="artist">Benson Boone</em>,
#  <em class="artist">Teddy Swims</em>,
#  <em class="artist">LAY &amp; Lauv</em>,
#  <em class="artist">Tucker Wetmore</em>,
#  <em class="artist">Tom MacDonald</em>,
#  <em class="artist">Beyoncé</em>,
#  <em class="artist">Jack Harlow</em>,
#  <em class="artist">Miley Cyrus</em>,
#  <em class="artist">Justin Timberlake</em>,
#  <em class="artist">Toby Keith</em>,
#  <em class="artist">Muni Long</em>,
#  <em class="artist">Benson Boone</em>,
#  <em class="artist">Luke Combs</em>,
#  <em class="artist">Benson Boone</em>,
#  <em class="artist">Benson Boone</em>,
#  <em class="artist">Justin Timberlake</em>,
#  <em class="artist">Selena Gomez</em>,
#  <em class="artist">Aaron Lewis</em>,
#  <em class="artist">Luke Combs</em>,
#  <em class="artist">Bailey Zimmerman</em>,
#  <em class="artist">BTS</em>,
#  <em class="artist">Dua Lipa</em>,
#  <em class="artist">Tim McGraw</em>,
#  <em class="artist">Zach Bryan</em>,
#  <em class="artist">LINKIN PARK</em>,
#  <em class="artist">Paul Russell</em>,
#  <em class="artist">French Montana, SAINt JHN &amp; Kanye West</em>,
#  <em class="artist">Taylor Swift</em>,
#  <em class="artist">Benson Boone</em>,
#  <em class="artist">Jelly Roll</em>,
#  <em class="artist">French Montana, Kanye West &amp; Westside Gunn</em>,
#  <em class="artist">Jelly Roll</em>,
#  <em class="artist">Benson Boone</em>,
#  <em class="artist">Forrest Frank</em>,
#  <em class="artist">Billy Joel</em>,
#  <em class="artist">mgk</em>,
#  <em class="artist">Jelly Roll</em>,
#  <em class="artist">Tracy Chapman</em>,
#  <em class="artist">Disturbed</em>,
#  <em class="artist">Morgan Wallen</em>,
#  <em class="artist">Morgan Wallen</em>,
#  <em class="artist">French Montana, Rick Ross &amp; Lil Wayne</em>,
#  <em class="artist">USHER</em>,
#  <em class="artist">Lainey Wilson</em>,
#  <em class="artist">Benson Boone</em>,
#  <em class="artist">Enrique Iglesias &amp; Miranda Lambert</em>,
#  <em class="artist">Warren Zeiders</em>,
#  <em class="artist">Chris Stapleton</em>,
#  <em class="artist">Beyoncé</em>,
#  <em class="artist">HARDY</em>,
#  <em class="artist">Sophie Ellis-Bextor</em>,
#  <em class="artist">Lee Brice</em>,
#  <em class="artist">Billie Eilish</em>,
#  <em class="artist">Noah Kahan</em>,
#  <em class="artist">Chris Stapleton</em>,
#  <em class="artist">Chayce Beckham</em>,
#  <em class="artist">Tyla</em>,
#  <em class="artist">Morgan Wallen</em>,
#  <em class="artist">Teddy Swims</em>,
#  <em class="artist">Dua Lipa</em>,
#  <em class="artist">Pitbull &amp; Dolly Parton</em>,
#  <em class="artist">Toby Keith</em>,
#  <em class="artist">YG Marley</em>,
#  <em class="artist">SZA</em>,
#  <em class="artist">Taylor Swift</em>,
#  <em class="artist">Hank Williams, Jr.</em>,
#  <em class="artist">Taylor Swift</em>,
#  <em class="artist">Jack Harlow</em>,
#  <em class="artist">Taylor Swift</em>,
#  <em class="artist">Skillet</em>,
#  <em class="artist">Dax</em>,
#  <em class="artist">Kelsey Hart</em>,
#  <em class="artist">Nate Smith</em>,
#  <em class="artist">Dave Matthews</em>,
#  <em class="artist">Taylor Swift</em>,
#  <em class="artist">Jason Derulo &amp; Michael Bublé</em>,
#  <em class="artist">Taylor Swift</em>,
#  <em class="artist">Rema &amp; Selena Gomez</em>,
#  <em class="artist">Tyler Braden</em>,
#  <em class="artist">Dua Lipa</em>,
#  <em class="artist">TWICE</em>,
#  <em class="artist">Doja Cat</em>,
#  <em class="artist">The Red Clay Strays</em>,
#  <em class="artist">21 Savage</em>,
#  <em class="artist">Dierks Bentley</em>,
#  <em class="artist">Taylor Swift</em>,
#  <em class="artist">Taylor Swift</em>,
#  <em class="artist">Lainey Wilson</em>,
#  <em class="artist">Olivia Rodrigo</em>,
#  <em class="artist">Shinedown</em>,
#  <em class="artist">Taylor Swift</em>,
#  <em class="artist">Sia</em>,
#  <em class="artist">Parker McCollum</em>,
#  <em class="artist">Jessie Murph &amp; Jelly Roll</em>,
#  <em class="artist">Tate McRae</em>,
#  <em class="artist">Michael Marcagi</em>,
#  <em class="artist">Natasha Bedingfield</em>,
#  <em class="artist">Miley Cyrus</em>,
#  <em class="artist">Ed Sheeran</em>]

# %%
len(soup.select('div.chart-content.col-xs-12.col-sm-8 > p > em'))
# Out:
# 100

# %%
songs = []
artists = []
for i in range(1,99):
    songs.append(soup.select('div.chart-content.col-xs-12.col-sm-8 > p > cite')[i].get_text())
    artists.append(soup.select('div.chart-content.col-xs-12.col-sm-8 > p > em')[i].get_text())

# %%
top100 = pd.DataFrame({'song':songs, 'artist':artists})

# %%
top100.head(10)
# Out:
#                        song             artist
# 0          Beautiful Things       Benson Boone
# 1              Lose Control        Teddy Swims
# 2           Run Back To You         LAY & Lauv
# 3         Wine Into Whiskey     Tucker Wetmore
# 4               The Machine      Tom MacDonald
# 5            TEXAS HOLD 'EM            Beyoncé
# 6               Lovin On Me        Jack Harlow
# 7                   Flowers        Miley Cyrus
# 8                     Drown  Justin Timberlake
# 9  Don't Let the Old Man In         Toby Keith

# %% [markdown]
# ### 2. RECOMENDER

# %%
wish = input("What song do you want?")
# Out:
# What song do you want?Tobogan

# %%
from random import randint  
def print_a_song(song_index):
    print(top100['song'][song_index],',', 'by', top100['artist'][song_index])

index = -1

try:
    index = (top100[top100['song'] == wish].index.values)[0]
except:
    print("The song is not in the list.")

if index >= 0:
    print_a_song(index)
else:
    random_song = randint(1, 100)
    print("Try this one:")
    print_a_song(random_song)
# Out:
# The song is not in the list.
# Try this one:
# 16 CARRIAGES , by Beyoncé

# %% [markdown]
# ### 3. Create your collection of songs & audio features

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /home/katherine/anaconda3/lib/python3.11/site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in /home/katherine/anaconda3/lib/python3.11/site-packages (from spotipy) (5.0.1)
# Requirement already satisfied: requests>=2.25.0 in /home/katherine/anaconda3/lib/python3.11/site-packages (from spotipy) (2.29.0)
# Requirement already satisfied: six>=1.15.0 in /home/katherine/anaconda3/lib/python3.11/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/katherine/anaconda3/lib/python3.11/site-packages (from spotipy) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/katherine/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/katherine/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/katherine/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (2023.5.7)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
playlist = sp.user_playlist_tracks("spotify", "3Q1DIJ51dJpUO6RhnIHdVx")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/3Q1DIJ51dJpUO6RhnIHdVx/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2020-09-13T02:40:33Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12172862942'},
#     'href': 'https://api.spotify.com/v1/users/12172862942',
#     'id': '12172862942',
#     'type': 'user',
#     'uri': 'spotify:user:12172862942'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eClJfHLoDI4rZe5HxzBFv'},
#        'href': 'https://api.spotify.com/v1/artists/1eClJfHLoDI4rZe5HxzBFv',
#        'id': '1eClJfHLoDI4rZe5HxzBFv',
#        'name': 'INXS',
#        'type': 'artist',
#        'uri': 'spotify:artist:1eClJfHLoDI4rZe5HxzBFv'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4fG8BOnqmBcUiIPilVZXlz'},
#      'href': 'https://api.spotify.com/v1/albums/4fG8BOnqmBcUiIPilVZXlz',
#      'id': '4fG8BOnqmBcUiIPilVZXlz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27325e91365800db257b2f43575',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0225e91365800db257b2f43575',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485125e91365800db257b2f43575',
#        'width': 64}],
#      'name': 'Shabooh Shoobah (Remastered)',
#      'release_date': '1982',
#      'release_date_precision': 'year',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4fG8BOnqmBcUiIPilVZXlz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eClJfHLoDI4rZe5HxzBFv'},
#       'href': 'https://api.spotify.com/v1/artists/1eClJfHLoDI4rZe5HxzBFv',
#       'id': '1eClJfHLoDI4rZe5HxzBFv',
#       'name': 'INXS',
#       'type': 'artist',
#       'uri': 'spotify:artist:1eClJfHLoDI4rZe5HxzBFv'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 268200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLF050190223'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2j7z87EnqB1NFQts2db0VR'},
#     'href': 'https://api.spotify.com/v1/tracks/2j7z87EnqB1NFQts2db0VR',
#     'id': '2j7z87EnqB1NFQts2db0VR',
#     'is_local': False,
#     'name': "Don't Change",
#     'popularity': 61,
#     'preview_url': None,
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:2j7z87EnqB1NFQts2db0VR'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-09-13T02:42:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12172862942'},
#     'href': 'https://api.spotify.com/v1/users/12172862942',
#     'id': '12172862942',
#     'type': 'user',
#     'uri': 'spotify:user:12172862942'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AR',
#       'AU',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'MT',
#       'MX',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PL',
#       'PT',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TR',
#       'UY',
#       'US',
#       'AD',
#       'LI',
#       'MC',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'MA',
#       'DZ',
#       'TN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'MR',
#       'MN',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/39P7VD7qlg3Z0ltq60eHp7'},
#      'href': 'https://api.spotify.com/v1/albums/39P7VD7qlg3Z0ltq60eHp7',
#      'id': '39P7VD7qlg3Z0ltq60eHp7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273801c4d205accdba0a468a10b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02801c4d205accdba0a468a10b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851801c4d205accdba0a468a10b',
#        'width': 64}],
#      'name': 'I AM...SASHA FIERCE',
#      'release_date': '2008-11-17',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:39P7VD7qlg3Z0ltq60eHp7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AR',
#      'AU',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'MT',
#      'MX',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PL',
#      'PT',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TR',
#      'UY',
#      'US',
#      'AD',
#      'LI',
#      'MC',
#      'JP',
#      'RO',
#      'IL',
#      'ZA',
#      'MA',
#      'DZ',
#      'TN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'ML',
#      'MH',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BI',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'MR',
#      'MN',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 261640,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10804556'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4JehYebiI9JE8sR8MisGVb'},
#     'href': 'https://api.spotify.com/v1/tracks/4JehYebiI9JE8sR8MisGVb',
#     'id': '4JehYebiI9JE8sR8MisGVb',
#     'is_local': False,
#     'name': 'Halo',
#     'popularity': 78,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6fd951cef00937cd2b7165a14f10d5e69239e5f7?cid=95b586f0f0964ac6b675c728b43b5121',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4JehYebiI9JE8sR8MisGVb'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-09-13T02:43:14Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12172862942'},
#     'href': 'https://api.spotify.com/v1/users/12172862942',
#     'id': '12172862942',
#     'type': 'user',
#     'uri': 'spotify:user:12172862942'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58lV9VcRSjABbAbfWS6skp'},
#        'href': 'https://api.spotify.com/v1/artists/58lV9VcRSjABbAbfWS6skp',
#        'id': '58lV9VcRSjABbAbfWS6skp',
#        'name': 'Bon Jovi',
#        'type': 'artist',
#        'uri': 'spotify:artist:58lV9VcRSjABbAbfWS6skp'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0Q9SljCrM0CL0bR23MuP69'},
#      'href': 'https://api.spotify.com/v1/albums/0Q9SljCrM0CL0bR23MuP69',
#      'id': '0Q9SljCrM0CL0bR23MuP69',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737a231174875d7930de9dad58',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027a231174875d7930de9dad58',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517a231174875d7930de9dad58',
#        'width': 64}],
#      'name': 'Crush',
#      'release_date': '2000-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0Q9SljCrM0CL0bR23MuP69'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58lV9VcRSjABbAbfWS6skp'},
#       'href': 'https://api.spotify.com/v1/artists/58lV9VcRSjABbAbfWS6skp',
#       'id': '58lV9VcRSjABbAbfWS6skp',
#       'name': 'Bon Jovi',
#       'type': 'artist',
#       'uri': 'spotify:artist:58lV9VcRSjABbAbfWS6skp'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 224493,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR20000145'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0v1XpBHnsbkCn7iJ9Ucr1l'},
#     'href': 'https://api.spotify.com/v1/tracks/0v1XpBHnsbkCn7iJ9Ucr1l',
#     'id': '0v1XpBHnsbkCn7iJ9Ucr1l',
#     'is_local': False,
#     'name': "It's My Life",
#     'popularity': 83,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0v1XpBHnsbkCn7iJ9Ucr1l'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-09-13T02:43:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12172862942'},
#     'href': 'https://api.spotify.com/v1/users/12172862942',
#     'id': '12172862942',
#     'type': 'user',
#     'uri': 'spotify:user:12172862942'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/57bUPid8xztkieZfS7OlEV'},
#        'href': 'https://api.spotify.com/v1/artists/57bUPid8xztkieZfS7OlEV',
#        'id': '57bUPid8xztkieZfS7OlEV',
#        'name': 'The Supremes',
#        'type': 'artist',
#        'uri': 'spotify:artist:57bUPid8xztkieZfS7OlEV'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/05pI1Rx1HQ4KA0a0e3PJlV'},
#      'href': 'https://api.spotify.com/v1/albums/05pI1Rx1HQ4KA0a0e3PJlV',
#      'id': '05pI1Rx1HQ4KA0a0e3PJlV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d5ea1215e77c3f7a7c716370',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d5ea1215e77c3f7a7c716370',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d5ea1215e77c3f7a7c716370',
#        'width': 64}],
#      'name': 'Where Did Our Love Go',
#      'release_date': '1964-08-31',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:05pI1Rx1HQ4KA0a0e3PJlV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/57bUPid8xztkieZfS7OlEV'},
#       'href': 'https://api.spotify.com/v1/artists/57bUPid8xztkieZfS7OlEV',
#       'id': '57bUPid8xztkieZfS7OlEV',
#       'name': 'The Supremes',
#       'type': 'artist',
#       'uri': 'spotify:artist:57bUPid8xztkieZfS7OlEV'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 153333,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMO19290049'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/69RH84na5iUNwrwxpgjC5j'},
#     'href': 'https://api.spotify.com/v1/tracks/69RH84na5iUNwrwxpgjC5j',
#     'id': '69RH84na5iUNwrwxpgjC5j',
#     'is_local': False,
#     'name': 'Where Did Our Love Go',
#     'popularity': 69,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:69RH84na5iUNwrwxpgjC5j'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-09-13T02:44:08Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12172862942'},
#     'href': 'https://api.spotify.com/v1/users/12172862942',
#     'id': '12172862942',
#     'type': 'user',
#     'uri': 'spotify:user:12172862942'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lZoBs4Pzo7R89JM9lxwoT'},
#        'href': 'https://api.spotify.com/v1/artists/0lZoBs4Pzo7R89JM9lxwoT',
#        'id': '0lZoBs4Pzo7R89JM9lxwoT',
#        'name': 'Duran Duran',
#        'type': 'artist',
#        'uri': 'spotify:artist:0lZoBs4Pzo7R89JM9lxwoT'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0PqCkTvKFJxzr9uujq7a3T'},
#      'href': 'https://api.spotify.com/v1/albums/0PqCkTvKFJxzr9uujq7a3T',
#      'id': '0PqCkTvKFJxzr9uujq7a3T',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c9647d4bd2589fa1c6e67333',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c9647d4bd2589fa1c6e67333',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c9647d4bd2589fa1c6e67333',
#        'width': 64}],
#      'name': 'Duran Duran',
#      'release_date': '1993-02-15',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0PqCkTvKFJxzr9uujq7a3T'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lZoBs4Pzo7R89JM9lxwoT'},
#       'href': 'https://api.spotify.com/v1/artists/0lZoBs4Pzo7R89JM9lxwoT',
#       'id': '0lZoBs4Pzo7R89JM9lxwoT',
#       'name': 'Duran Duran',
#       'type': 'artist',
#       'uri': 'spotify:artist:0lZoBs4Pzo7R89JM9lxwoT'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 340200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE9200048'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0wokCRaKD0zPNhMRXAgVsr'},
#     'href': 'https://api.spotify.com/v1/tracks/0wokCRaKD0zPNhMRXAgVsr',
#     'id': '0wokCRaKD0zPNhMRXAgVsr',
#     'is_local': False,
#     'name': 'Ordinary World',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b406928c447e95dedc75e8460160dd70b5fa2c65?cid=95b586f0f0964ac6b675c728b43b5121',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0wokCRaKD0zPNhMRXAgVsr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-09-13T02:44:31Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12172862942'},
#     'href': 'https://api.spotify.com/v1/users/12172862942',
#     'id': '12172862942',
#     'type': 'user',
#     'uri': 'spotify:user:12172862942'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#        'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#        'id': '3fMbdgg4jU18AjLCKBhRSm',
#        'name': 'Michael Jackson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0oX4SealMgNXrvRDhqqOKg'},
#      'href': 'https://api.spotify.com/v1/albums/0oX4SealMgNXrvRDhqqOKg',
#      'id': '0oX4SealMgNXrvRDhqqOKg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733b9f8b18cc685e1502128aa8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023b9f8b18cc685e1502128aa8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513b9f8b18cc685e1502128aa8',
#        'width': 64}],
#      'name': 'Dangerous',
#      'release_date': '1991-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0oX4SealMgNXrvRDhqqOKg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#       'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#       'id': '3fMbdgg4jU18AjLCKBhRSm',
#       'name': 'Michael Jackson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 254933,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19000733'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7EsjkelQuoUlJXEw7SeVV4'},
#     'href': 'https://api.spotify.com/v1/tracks/7EsjkelQuoUlJXEw7SeVV4',
#     'id': '7EsjkelQuoUlJXEw7SeVV4',
#     'is_local': False,
#     'name': 'Black or White',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/563eb405b53bb155973d815009ce476708b1724f?cid=95b586f0f0964ac6b675c728b43b5121',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:7EsjkelQuoUlJXEw7SeVV4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-09-13T02:50:47Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12172862942'},
#     'href': 'https://api.spotify.com/v1/users/12172862942',
#     'id': '12172862942',
#     'type': 'user',
#     'uri': 'spotify:user:12172862942'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0GByy3DcfbQwDvXGCWmzv9'},
#        'href': 'https://api.spotify.com/v1/artists/0GByy3DcfbQwDvXGCWmzv9',
#        'id': '0GByy3DcfbQwDvXGCWmzv9',
#        'name': 'Pretenders',
#        'type': 'artist',
#        'uri': 'spotify:artist:0GByy3DcfbQwDvXGCWmzv9'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Qo4xIO7aWMVcbelqpTdGY'},
#      'href': 'https://api.spotify.com/v1/albums/1Qo4xIO7aWMVcbelqpTdGY',
#      'id': '1Qo4xIO7aWMVcbelqpTdGY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a242478e02cda5e7535576ac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a242478e02cda5e7535576ac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a242478e02cda5e7535576ac',
#        'width': 64}],
#      'name': 'The Singles',
#      'release_date': '1987-10-26',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:1Qo4xIO7aWMVcbelqpTdGY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0GByy3DcfbQwDvXGCWmzv9'},
#       'href': 'https://api.spotify.com/v1/artists/0GByy3DcfbQwDvXGCWmzv9',
#       'id': '0GByy3DcfbQwDvXGCWmzv9',
#       'name': 'Pretenders',
#       'type': 'artist',
#       'uri': 'spotify:artist:0GByy3DcfbQwDvXGCWmzv9'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 226066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT8603594'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4I3nztDQ3cPajQtzg59tWx'},
#     'href': 'https://api.spotify.com/v1/tracks/4I3nztDQ3cPajQtzg59tWx',
#     'id': '4I3nztDQ3cPajQtzg59tWx',
#     'is_local': False,
#     'name': "Don't Get Me Wrong",
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e8478bf2f690565a66b324f0e35ca883bbccd05c?cid=95b586f0f0964ac6b675c728b43b5121',
#     'track': True,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:4I3nztDQ3cPajQtzg59tWx'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-09-13T02:51:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12172862942'},
#     'href': 'https://api.spotify.com/v1/users/12172862942',
#     'id': '12172862942',
#     'type': 'user',
#     'uri': 'spotify:user:12172862942'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1aSxMhuvixZ8h9dK9jIDwL'},
#        'href': 'https://api.spotify.com/v1/artists/1aSxMhuvixZ8h9dK9jIDwL',
#        'id': '1aSxMhuvixZ8h9dK9jIDwL',
#        'name': 'Kate Bush',
#        'type': 'artist',
#        'uri': 'spotify:artist:1aSxMhuvixZ8h9dK9jIDwL'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5BWl0bB1q0TqyFmkBEupZy'},
#      'href': 'https://api.spotify.com/v1/albums/5BWl0bB1q0TqyFmkBEupZy',
#      'id': '5BWl0bB1q0TqyFmkBEupZy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27396ab64f52273635308b6bf27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0296ab64f52273635308b6bf27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485196ab64f52273635308b6bf27',
#        'width': 64}],
#      'name': 'Hounds Of Love',
#      'release_date': '1985',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5BWl0bB1q0TqyFmkBEupZy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1aSxMhuvixZ8h9dK9jIDwL'},
#       'href': 'https://api.spotify.com/v1/artists/1aSxMhuvixZ8h9dK9jIDwL',
# ...
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 202640,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71109132'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1r299qCKBLgUS9XJ9m1kEx'},
#     'href': 'https://api.spotify.com/v1/tracks/1r299qCKBLgUS9XJ9m1kEx',
#     'id': '1r299qCKBLgUS9XJ9m1kEx',
#     'is_local': False,
#     'name': 'Moves Like Jagger',
#     'popularity': 72,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:1r299qCKBLgUS9XJ9m1kEx'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-09-13T04:15:52Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12172862942'},
#     'href': 'https://api.spotify.com/v1/users/12172862942',
#     'id': '12172862942',
#     'type': 'user',
#     'uri': 'spotify:user:12172862942'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eClJfHLoDI4rZe5HxzBFv'},
#        'href': 'https://api.spotify.com/v1/artists/1eClJfHLoDI4rZe5HxzBFv',
#        'id': '1eClJfHLoDI4rZe5HxzBFv',
#        'name': 'INXS',
#        'type': 'artist',
#        'uri': 'spotify:artist:1eClJfHLoDI4rZe5HxzBFv'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3GSxZlsQkGEjkHa09sdwRP'},
#      'href': 'https://api.spotify.com/v1/albums/3GSxZlsQkGEjkHa09sdwRP',
#      'id': '3GSxZlsQkGEjkHa09sdwRP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739f41eabd4e8f9ba656f4f995',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029f41eabd4e8f9ba656f4f995',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519f41eabd4e8f9ba656f4f995',
#        'width': 64}],
#      'name': 'The Swing',
#      'release_date': '1984',
#      'release_date_precision': 'year',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3GSxZlsQkGEjkHa09sdwRP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eClJfHLoDI4rZe5HxzBFv'},
#       'href': 'https://api.spotify.com/v1/artists/1eClJfHLoDI4rZe5HxzBFv',
#       'id': '1eClJfHLoDI4rZe5HxzBFv',
#       'name': 'INXS',
#       'type': 'artist',
#       'uri': 'spotify:artist:1eClJfHLoDI4rZe5HxzBFv'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 202426,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLF050190176'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6COoRaCNma7V9sBf81y9EK'},
#     'href': 'https://api.spotify.com/v1/tracks/6COoRaCNma7V9sBf81y9EK',
#     'id': '6COoRaCNma7V9sBf81y9EK',
#     'is_local': False,
#     'name': 'I Send A Message',
#     'popularity': 44,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6COoRaCNma7V9sBf81y9EK'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-09-13T04:16:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12172862942'},
#     'href': 'https://api.spotify.com/v1/users/12172862942',
#     'id': '12172862942',
#     'type': 'user',
#     'uri': 'spotify:user:12172862942'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6prmLEyn4LfHlD9NnXWlf7'},
#        'href': 'https://api.spotify.com/v1/artists/6prmLEyn4LfHlD9NnXWlf7',
#        'id': '6prmLEyn4LfHlD9NnXWlf7',
#        'name': 'Adam Lambert',
#        'type': 'artist',
#        'uri': 'spotify:artist:6prmLEyn4LfHlD9NnXWlf7'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0cUNjl7p6LYZJkKXJWzqP0'},
#      'href': 'https://api.spotify.com/v1/albums/0cUNjl7p6LYZJkKXJWzqP0',
#      'id': '0cUNjl7p6LYZJkKXJWzqP0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fe0d9870d6d8e18c3a00c658',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fe0d9870d6d8e18c3a00c658',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fe0d9870d6d8e18c3a00c658',
#        'width': 64}],
#      'name': 'For Your Entertainment',
#      'release_date': '2009-11-23',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0cUNjl7p6LYZJkKXJWzqP0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6prmLEyn4LfHlD9NnXWlf7'},
#       'href': 'https://api.spotify.com/v1/artists/6prmLEyn4LfHlD9NnXWlf7',
#       'id': '6prmLEyn4LfHlD9NnXWlf7',
#       'name': 'Adam Lambert',
#       'type': 'artist',
#       'uri': 'spotify:artist:6prmLEyn4LfHlD9NnXWlf7'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 227320,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCTA0900344'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2rDwdvBma1O1eLzo29p2cr'},
#     'href': 'https://api.spotify.com/v1/tracks/2rDwdvBma1O1eLzo29p2cr',
#     'id': '2rDwdvBma1O1eLzo29p2cr',
#     'is_local': False,
#     'name': 'Whataya Want from Me',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4b8ab1b810185612247ce9e6cca444149eaf0a52?cid=95b586f0f0964ac6b675c728b43b5121',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2rDwdvBma1O1eLzo29p2cr'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/3Q1DIJ51dJpUO6RhnIHdVx/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 1012}

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist["items"][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
playlist["items"][0]["track"]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eClJfHLoDI4rZe5HxzBFv'},
#     'href': 'https://api.spotify.com/v1/artists/1eClJfHLoDI4rZe5HxzBFv',
#     'id': '1eClJfHLoDI4rZe5HxzBFv',
#     'name': 'INXS',
#     'type': 'artist',
#     'uri': 'spotify:artist:1eClJfHLoDI4rZe5HxzBFv'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4fG8BOnqmBcUiIPilVZXlz'},
#   'href': 'https://api.spotify.com/v1/albums/4fG8BOnqmBcUiIPilVZXlz',
#   'id': '4fG8BOnqmBcUiIPilVZXlz',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27325e91365800db257b2f43575',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0225e91365800db257b2f43575',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485125e91365800db257b2f43575',
#     'width': 64}],
#   'name': 'Shabooh Shoobah (Remastered)',
#   'release_date': '1982',
#   'release_date_precision': 'year',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:4fG8BOnqmBcUiIPilVZXlz'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eClJfHLoDI4rZe5HxzBFv'},
#    'href': 'https://api.spotify.com/v1/artists/1eClJfHLoDI4rZe5HxzBFv',
#    'id': '1eClJfHLoDI4rZe5HxzBFv',
#    'name': 'INXS',
#    'type': 'artist',
#    'uri': 'spotify:artist:1eClJfHLoDI4rZe5HxzBFv'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 268200,
#  'episode': False,
#  'explicit': False,
#  'external_ids': {'isrc': 'NLF050190223'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2j7z87EnqB1NFQts2db0VR'},
#  'href': 'https://api.spotify.com/v1/tracks/2j7z87EnqB1NFQts2db0VR',
#  'id': '2j7z87EnqB1NFQts2db0VR',
#  'is_local': False,
#  'name': "Don't Change",
#  'popularity': 61,
#  'preview_url': None,
#  'track': True,
#  'track_number': 10,
#  'type': 'track',
#  'uri': 'spotify:track:2j7z87EnqB1NFQts2db0VR'}

# %%
playlist["items"][0]['track']['artists'][0]['name']
# Out:
# 'INXS'

# %%
playlist["items"][0]["track"]["name"]
# Out:
# "Don't Change"

# %%
playlist["total"]
# Out:
# 1012

# %%
playlist["next"]
# Out:
# 'https://api.spotify.com/v1/playlists/3Q1DIJ51dJpUO6RhnIHdVx/tracks?offset=100&limit=100&additional_types=track'

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
all_tracks = get_playlist_tracks("3Q1DIJ51dJpUO6RhnIHdVx")
len(all_tracks)
# Out:
# 1012

# %%
import pandas as pd
from pandas import json_normalize
pd.set_option("display.max_columns", 0)

# %%
tracks = json_normalize(all_tracks)

# %%
tracks.columns
# Out:
# Index(['added_at', 'is_local', 'primary_color',
#        'added_by.external_urls.spotify', 'added_by.href', 'added_by.id',
#        'added_by.type', 'added_by.uri', 'track.album.album_type',
#        'track.album.artists', 'track.album.available_markets',
#        'track.album.external_urls.spotify', 'track.album.href',
#        'track.album.id', 'track.album.images', 'track.album.name',
#        'track.album.release_date', 'track.album.release_date_precision',
#        'track.album.total_tracks', 'track.album.type', 'track.album.uri',
#        'track.artists', 'track.available_markets', 'track.disc_number',
#        'track.duration_ms', 'track.episode', 'track.explicit',
#        'track.external_ids.isrc', 'track.external_urls.spotify', 'track.href',
#        'track.id', 'track.is_local', 'track.name', 'track.popularity',
#        'track.preview_url', 'track.track', 'track.track_number', 'track.type',
#        'track.uri', 'video_thumbnail.url'],
#       dtype='object')

# %%
artists_df1 = pd.DataFrame(columns=['track.name', 'track.id', 'track.popularity'])
for i in tracks.index:
    artists_for_song = json_normalize(tracks.iloc[i]['track.artists'])
    artists_for_song['song_id']    = tracks.iloc[i]['track.id']         
    artists_for_song['song_name']  = tracks.iloc[i]['track.name']       
    artists_for_song['popularity'] = tracks.iloc[i]['track.popularity']

    artists_df1 = pd.concat([artists_df1, artists_for_song], axis=0)

# %%
artists_df1.to_csv('artists_df1.csv', index=False)

# %%
data = pd.read_csv('artists_df1.csv')

# %%
data.isna().sum()
# Out:
# track.name               1100
# track.id                 1100
# track.popularity         1100
# href                        0
# id                          0
# name                        0
# type                        0
# uri                         0
# external_urls.spotify       0
# song_id                     0
# song_name                   0
# popularity                  0
# dtype: int64

# %%
data.dropna(subset=['song_id'], inplace=True)

# %%
data.drop(['track.name', 'track.id', 'track.popularity'], axis=1, inplace=True)

# %%
data.head(10)
# Out:
#                                                 href  ... popularity
# 0  https://api.spotify.com/v1/artists/1eClJfHLoDI...  ...       61.0
# 1  https://api.spotify.com/v1/artists/6vWDO969PvN...  ...       78.0
# 2  https://api.spotify.com/v1/artists/58lV9VcRSjA...  ...       83.0
# 3  https://api.spotify.com/v1/artists/57bUPid8xzt...  ...       69.0
# 4  https://api.spotify.com/v1/artists/0lZoBs4Pzo7...  ...       77.0
# 5  https://api.spotify.com/v1/artists/3fMbdgg4jU1...  ...       72.0
# 6  https://api.spotify.com/v1/artists/0GByy3DcfbQ...  ...       42.0
# 7  https://api.spotify.com/v1/artists/1aSxMhuvixZ...  ...       11.0
# 8  https://api.spotify.com/v1/artists/3AQRLZ9PuTA...  ...       84.0
# 9  https://api.spotify.com/v1/artists/085pc2PYOi8...  ...       84.0
#
# [10 rows x 9 columns]

# %%
len(data)
# Out:
# 1100

# %%
data = data.drop(['href','type','uri','external_urls.spotify'], axis=1)

# %%
chunks = [(i, i+10000) for i in range(0, len(data), 10000)]
chunks
audio_features_list = []
for chunk in chunks:
    id_list100 = data['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:879, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     878 try:
# --> 879     retries = retries.increment(method, url, response=response, _pool=self)
#     880 except MaxRetryError:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids
MkU,5JvsxPAHsGxwNq4xto2HtM,7iBav4v8maicL8cWKGxFhQ,2QUenCbs1tWfw1cQE4pV8C,2QUenCbs1tWfw1cQE4pV8C,2BgWv15eKCDfiubKo6o76k,4w2Yq2cklbssmUtUy5Vh6H,7uHO4AmKtyGa5v5fsElGoC,3bTC0dp9O6QH9YnOtrikc8,3J19l4hOfwFFIF715BwVcG,1FvDJ9KGxcqwv1utyPL3JZ,1MTQHCpraD4S8g5PAFKzoj,55JYAswiVAIhO8mK2VVLe1,4D40ZlFAWsvX7lua1Kablh,4D40ZlFAWsvX7lua1Kablh,1VA38sp5Jr6vWxgoIcnxKN,1Qrdlkgg9I4J7r3P4kZNwr,5OQsiBsky2k2kDKy2bX2eT,4HA2jo7wkMdN1lmLO6ryzE,3YKptz29AsOlm7WAVnztBh,5ZDL1Ap2Mwhk5xhmQ41Ei2,1HChuZvDKwcl76LvaGExeo,4ePP9So5xRzspjLFVVbj90,5WwqdeavrQrbeAMDxGawse,1w1LOtv2BM2C5pK4LG7SJ6,6vGW3d8X48CBaLdU0PQbey,00cn1ynXQhURwsgv69fN0b,2n6FX3Jcg4b4Leoz0GOqBF,2Q5wSOwq6BDSu7sSVMNrtT,48UPSzbZjgc449aqz8bxox,0Pu71wxadDlB8fJXfjIjeJ,4TIJ7zSBNejpoIPaWpWRKc,6KEWtSOGKpIXGw6l1uJgsR,2M9ro2krNb7nr7HSprkEgo,5VYTKiOnHw4iTrB9pG3yum,1D4PL9B8gOg78jiHg3FvBb,3BjFRts9fRjcmkiBfjTR5H,3BjFRts9fRjcmkiBfjTR5H,2HcyIzVsX45jLIxK7SH2aI,4c6vZqYHFur11FbWATIJ9P,5vmRQ3zELMLUQPo2FLQ76x,72YATNrv9D0QIVgOURyTFg,7clUVcSOtkNWa58Gw5RfD4,3ZqGaV6I9FgRur ...
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[162], line 6
#       4 for chunk in chunks:
#       5     id_list100 = data['song_id'][chunk[0]:chunk[1]]
# ----> 6     audio_features_list = audio_features_list + sp.audio_features(id_list100)
#       7     sleep(randint(1,3000)/1000)
#       8 len(audio_features_list)
#
# File ~/anaconda3/lib/python3.11/site-packages/spotipy/client.py:1737, in Spotify.audio_features(self, tracks)
#    1735 else:
#    1736     tlist = [self._get_id("track", t) for t in tracks]
# -> 1737     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1738 # the response has changed, look for the new style first, and if
#    1739 # its not there, fallback on the old style
#    1740 if "audio_features" in results:
#
# File ~/anaconda3/lib/python3.11/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/spotipy/client.py:307, in Spotify._internal_call(self, method, url, payload, params)
#     305     except (IndexError, AttributeError):
#     306         reason = None
# --> 307     raise SpotifyException(
#     308         429,
#     309         -1,
#     310         "%s:\n %s" % (request.path_url, "Max Retries"),
#     311         reason=reason
#     312     )
#     313 except ValueError:
#     314     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=2j7z87EnqB1NFQts2db0VR,4JehYebiI9JE8sR8MisGVb,0v1XpBHnsbkCn7iJ9Ucr1l,69RH84na5iUNwrwxpgjC5j,0wokCRaKD0zPNhMRXAgVsr,7EsjkelQuoUlJXEw7SeVV4,4I3nztDQ3cPajQtzg59tWx,75FEaRjZTKLhTrFGsfMUXR,7wMq5n8mYSKlQIGECKUgTX,7wMq5n8mYSKlQIGECKUgTX,2KH16WveTQWT6KOG9Rg6e2,2Ms33RTRCT6gArrpcrPxmo,15tHagkk8z306XkyOHqiip,303ccTay2FiDTZ9fZ2AdBt,303ccTay2FiDTZ9fZ2AdBt,303ccTay2FiDTZ9fZ2AdBt
8fJXfjIjeJ,4TIJ7zSBNejpoIPaWpWRKc,6KEWtSOGKpIXGw6l1uJgsR,2M9ro2krNb7nr7HSprkEgo,5VYTKiOnHw4iTrB9pG3yum,1D4PL9B8gOg78jiHg3FvBb,3BjFRts9fRjcmkiBfjTR5H,3BjFRts9fRjcmkiBfjTR5H,2HcyIzVsX45jLIxK7SH2aI,4c6vZqYHFur11FbWATIJ9P,5vmRQ3zELMLUQPo2FLQ76x,72YATNrv9D0QIVgOURyTFg,7clUVcSOtkNWa58Gw5RfD4,3ZqGaV6I9FgRureoCBPzuF,7vVYqVFAdEFbiAMh8aPFaJ,00tpqOHmO4WLMI93JOZF ...
#  Max Retries, reason: too many 502 error responses

# %%
audio_features_df = json_normalize(audio_features_list)

# %%
audio_features_df.drop_duplicates(inplace=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
audio_features_df.columns
# Out:
# Index([], dtype='object')

# %%
df_w_audio_ft = pd.merge(left=data,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 df_w_audio_ft = pd.merge(left=data,
#       2                         right=audio_features_df,
#       3                         how='inner',
#       4                         left_on='song_id',
#       5                         right_on='id')
#       6 df_w_audio_ft
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'id'

# %% [markdown]
# ### 4. Clustering: Unsupervised learning intro

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
X_cluster = df_w_audio_ft.select_dtypes(include=np.number) #numeric features to apply the model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 X_cluster = df_w_audio_ft.select_dtypes(include=np.number)
#
# NameError: name 'df_w_audio_ft' is not defined

# %%
X_cluster
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 X_cluster
#
# NameError: name 'X_cluster' is not defined

# %%
# X_cluster_droped = X_cluster.drop(['time_signature'], axis=1)
# X_cluster_droped.head(5)

# %%
from sklearn.preprocessing import StandardScaler
X_prep = StandardScaler().fit_transform(X_cluster_droped)

pd.DataFrame(X_prep,columns=X_cluster_droped.columns).head()

# %%
X_prep

# %%
# from sklearn.preprocessing import MinMaxScaler

# # Escalado de los datos (por ejemplo, estandarización)
# scaler = StandardScaler()
# data_scaled = scaler.fit_transform(X_prep)

# # Normalización Min-Max
# min_max_scaler = MinMaxScaler()
# X_prepn = min_max_scaler.fit_transform(data_scaled)

# %%
X_prep

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=6, random_state=1234)
kmeans.fit(X_prep)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X_prep)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()

# %%
clusters

# %%
plt.figure(figsize=(5, 5))
plt.scatter(X_prepn[:, 0], X_prepn[:, 11], c=clusters,alpha=0.5)
plt.show()

# %%
kmeans.inertia_

# %%
# %%time
kmeans = KMeans(n_clusters=6,
                init="random",
                n_init= 4,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=10,
                tol=0,
                random_state=1234)
kmeans.fit(X_prep)
print(kmeans.inertia_)

# %%
import numpy as np
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prepn)
    silhouette.append(silhouette_score(X_prepn, kmeans.predict(X_prepn)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')
